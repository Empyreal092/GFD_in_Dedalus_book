# %% [markdown]
# # The Eady instability
#
# We use Dedalus to solve the classic Eady baroclinic instability problem.
# For the Eady problem, the PV is assumed to be zero. Therefore we only
# have the advection of the buoyancy on the top and bottom. We refer to
# {cite:t}`Vallis_17` §9.5 for more details on the set-up of the problem and the
# algebraic solution. Here we use Dedalus to recover their result.

# %%
import numpy as np
import dedalus.public as d3

import matplotlib
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import cmocean.cm as cmo

plt.style.use('../subroutine/ryan_mplstyle.mplstyle')

# %%
# Numerics Parameters
Lz = 1
Nz = 128

dtype = np.complex128

# Bases
Lzt, Lzb = 0, -Lz

coords = d3.CartesianCoordinates('z')
dist = d3.Distributor(coords, dtype=dtype)
zbasis = d3.Chebyshev(coords['z'], size=Nz, bounds=(Lzb, Lzt))

# %% [markdown]
# We define the fields

# %%
# Fields
omega = dist.Field()

q = dist.Field(name='q', bases=zbasis )
bt = dist.Field(name='bt' )
bb = dist.Field(name='bb' )

P0 = dist.Field(name='P0', bases=zbasis )

tau_P0 = dist.Field()
tau_P0t = dist.Field( )
tau_P0b = dist.Field( )

kx = dist.Field(name='kx')
ky = dist.Field(name='ky')
omega = dist.Field()

# %% [markdown]
# Note that for since we assumed the Fourier ansatz, $x$, $y$, and $t$-derivatives are replaced with miltiplication of $ik$, $i\ell$, and $-i\omega$.

# %%
# Substitutions
dx = lambda A: 1j*kx*A
dy = lambda A: 1j*ky*A
dz = lambda A: d3.Differentiate(A, coords['z'])
dt = lambda A: -1j*omega*A

z = dist.local_grids(zbasis)

lift_basis = zbasis.derivative_basis(2)
lift = lambda A, n: d3.Lift(A, lift_basis, n)

u = -dy(P0)
v =  dx(P0)

ut = u(z=Lzt); vt = v(z=Lzt); 
ub = u(z=Lzb); vb = v(z=Lzb); 

lap = lambda A: dx(dx(A))+dy(dy(A))+dz(dz(A))

# %% [markdown]
# Here we type out the linear instability problem. Note the use of tau fields to enforce the top and bottom boundary conditions.

# %%
# Problem
problem = d3.EVP([P0, tau_P0t, tau_P0b, \
                  bt, bb \
                  ], eigenvalue=omega, namespace=locals())

problem.add_equation("lap(P0) + lift(tau_P0t,-1) + lift(tau_P0b,-2) = 0")
problem.add_equation("dz(P0)(z=Lzt) - bt = 0"); problem.add_equation("dz(P0)(z=Lzb) - bb = 0")

problem.add_equation("dt(bt) + Lzt*dx(bt)-vt = 0")
problem.add_equation("dt(bb) + Lzb*dx(bb)-vb = 0")
# Out:
# {'eqn': Add(Add(Mul(Mul((-0-1j), <Field 134250387864896>), <Field 134250398235568>), Mul(-1, Mul(Mul(1j, <Field 134250388184400>), <Field 134250398235568>))), Mul(-1, interp(Mul(Mul(1j, <Field 134250388184400>), <Field 134250388118736>), z=-1))),
#  'LHS': Add(Add(Mul(Mul((-0-1j), <Field 134250387864896>), <Field 134250398235568>), Mul(-1, Mul(Mul(1j, <Field 134250388184400>), <Field 134250398235568>))), Mul(-1, interp(Mul(Mul(1j, <Field 134250388184400>), <Field 134250388118736>), z=-1))),
#  'RHS': 0,
#  'condition': 'True',
#  'tensorsig': (),
#  'dtype': dtype('complex128'),
#  'valid_modes': array([ True]),
#  'M': Mul((-0-1j), <Field 134250398235568>),
#  'L': Add(Mul(-1, Mul(Mul(1j, <Field 134250388184400>), <Field 134250398235568>)), Mul(-1, interp(Mul(Mul(1j, <Field 134250388184400>), <Field 134250388118736>), z=-1))),
#  'domain': <dedalus.core.domain.Domain at 0x7a19cbd1a270>,
#  'matrix_dependence': array([ True]),
#  'matrix_coupling': array([ True])}

# %% [markdown]
# For each wavenumber $k$, we perform one Dedalus solve and find the most unstable vertical mode. This is done for a range of horizontal wavenumber $k$.

# %%
# Solver
k_ary = np.arange(0.01,4,0.03)
grow_ary = np.empty([k_ary.size])
c_ary_1 = np.empty([k_ary.size], dtype=complex)
c_ary_2 = np.empty([k_ary.size], dtype=complex)

for ix in range(k_ary.size):
    kx['g'] = k_ary[ix]; ky['g'] = 0

    solver = problem.build_solver()
    solver.solve_dense(solver.subproblems[0], rebuild_matrices=True)
    evals = solver.eigenvalues
    # print(evals.shape)

    e_loc = np.argmax(np.imag(evals))
    grow_ary[ix] = np.imag(evals[e_loc])
    
    if abs(np.imag(evals[e_loc])) > 1e-15:
        c_ary_1[ix] = evals[e_loc]/k_ary[ix]
        c_ary_2[ix] = evals[e_loc]/k_ary[ix]
    else:
        c_ary_1[ix] = np.min(evals[evals<np.inf])/k_ary[ix]
        c_ary_2[ix] = np.max(evals[evals<np.inf])/k_ary[ix]
# Out:
# 2025-06-12 10:08:59,215 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 2.4e+01/s
# 2025-06-12 10:08:59,259 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.5e+01/s
# 2025-06-12 10:08:59,297 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 7.1e+01/s
# 2025-06-12 10:08:59,330 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 8.2e+01/s
# 2025-06-12 10:08:59,366 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.7e+01/s
# 2025-06-12 10:08:59,405 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.7e+01/s
# 2025-06-12 10:08:59,444 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.9e+01/s
# 2025-06-12 10:08:59,484 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.5e+01/s
# 2025-06-12 10:08:59,522 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 7.0e+01/s
# 2025-06-12 10:08:59,561 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.9e+01/s
# 2025-06-12 10:08:59,599 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 7.2e+01/s
# 2025-06-12 10:08:59,635 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 7.7e+01/s
# 2025-06-12 10:08:59,670 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.9e+01/s
# 2025-06-12 10:08:59,709 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 7.0e+01/s
# 2025-06-12 10:08:59,744 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 8.3e+01/s
# 2025-06-12 10:08:59,776 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 8.1e+01/s
# 2025-06-12 10:08:59,813 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.1e+01/s
# 2025-06-12 10:08:59,852 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.7e+01/s
# 2025-06-12 10:08:59,891 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.8e+01/s
# 2025-06-12 10:08:59,928 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 7.1e+01/s
# 2025-06-12 10:08:59,960 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 8.3e+01/s
# 2025-06-12 10:08:59,993 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 7.3e+01/s
# 2025-06-12 10:09:00,027 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.9e+01/s
# 2025-06-12 10:09:00,069 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.0e+01/s
# 2025-06-12 10:09:00,109 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.2e+01/s
# 2025-06-12 10:09:00,150 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.8e+01/s
# 2025-06-12 10:09:00,191 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.2e+01/s
# 2025-06-12 10:09:00,230 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.4e+01/s
# 2025-06-12 10:09:00,268 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 7.2e+01/s
# 2025-06-12 10:09:00,303 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 7.9e+01/s
# 2025-06-12 10:09:00,335 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 7.9e+01/s
# 2025-06-12 10:09:00,367 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 8.4e+01/s
# 2025-06-12 10:09:00,401 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 7.8e+01/s
# 2025-06-12 10:09:00,434 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 7.6e+01/s
# 2025-06-12 10:09:00,466 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 8.3e+01/s
# 2025-06-12 10:09:00,498 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 8.2e+01/s
# 2025-06-12 10:09:00,529 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 8.4e+01/s
# 2025-06-12 10:09:00,562 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 8.3e+01/s
# 2025-06-12 10:09:00,594 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 8.2e+01/s
# 2025-06-12 10:09:00,626 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 8.4e+01/s
# 2025-06-12 10:09:00,659 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 7.9e+01/s
# 2025-06-12 10:09:00,692 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 8.3e+01/s
# 2025-06-12 10:09:00,726 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 7.3e+01/s
# 2025-06-12 10:09:00,766 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.5e+01/s
# 2025-06-12 10:09:00,804 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.9e+01/s
# 2025-06-12 10:09:00,842 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 7.5e+01/s
# 2025-06-12 10:09:00,874 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 8.5e+01/s
# 2025-06-12 10:09:00,906 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 7.8e+01/s
# 2025-06-12 10:09:00,941 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 7.0e+01/s
# 2025-06-12 10:09:00,973 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 8.1e+01/s
# 2025-06-12 10:09:01,006 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 7.9e+01/s
# 2025-06-12 10:09:01,041 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 7.0e+01/s
# 2025-06-12 10:09:01,081 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.6e+01/s
# 2025-06-12 10:09:01,122 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.3e+01/s
# 2025-06-12 10:09:01,160 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 7.0e+01/s
# 2025-06-12 10:09:01,196 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 7.2e+01/s
# 2025-06-12 10:09:01,231 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 8.3e+01/s
# 2025-06-12 10:09:01,270 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.5e+01/s
# 2025-06-12 10:09:01,309 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.8e+01/s
# 2025-06-12 10:09:01,347 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 7.0e+01/s
# 2025-06-12 10:09:01,386 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.9e+01/s
# 2025-06-12 10:09:01,424 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.8e+01/s
# 2025-06-12 10:09:01,463 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 7.0e+01/s
# 2025-06-12 10:09:01,501 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.9e+01/s
# 2025-06-12 10:09:01,539 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 7.1e+01/s
# 2025-06-12 10:09:01,581 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.8e+01/s
# 2025-06-12 10:09:01,619 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 7.1e+01/s
# 2025-06-12 10:09:01,653 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 8.4e+01/s
# 2025-06-12 10:09:01,685 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 8.5e+01/s
# 2025-06-12 10:09:01,717 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 8.1e+01/s
# 2025-06-12 10:09:01,751 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 7.3e+01/s
# 2025-06-12 10:09:01,782 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 8.3e+01/s
# 2025-06-12 10:09:01,814 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 8.0e+01/s
# 2025-06-12 10:09:01,848 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 7.6e+01/s
# 2025-06-12 10:09:01,882 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 8.1e+01/s
# 2025-06-12 10:09:01,915 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 8.2e+01/s
# 2025-06-12 10:09:01,953 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.7e+01/s
# 2025-06-12 10:09:01,993 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.8e+01/s
# 2025-06-12 10:09:02,032 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.9e+01/s
# 2025-06-12 10:09:02,070 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 7.1e+01/s
# 2025-06-12 10:09:02,108 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.8e+01/s
# 2025-06-12 10:09:02,147 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.9e+01/s
# 2025-06-12 10:09:02,186 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.7e+01/s
# 2025-06-12 10:09:02,224 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.6e+01/s
# 2025-06-12 10:09:02,257 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 8.4e+01/s
# 2025-06-12 10:09:02,290 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 8.2e+01/s
# 2025-06-12 10:09:02,323 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 8.2e+01/s
# 2025-06-12 10:09:02,357 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 7.4e+01/s
# 2025-06-12 10:09:02,389 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 7.9e+01/s
# 2025-06-12 10:09:02,420 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 8.4e+01/s
# 2025-06-12 10:09:02,453 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 7.7e+01/s
# 2025-06-12 10:09:02,485 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 8.3e+01/s
# 2025-06-12 10:09:02,519 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 7.6e+01/s
# 2025-06-12 10:09:02,551 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 8.2e+01/s
# 2025-06-12 10:09:02,583 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 8.4e+01/s
# 2025-06-12 10:09:02,615 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 8.3e+01/s
# 2025-06-12 10:09:02,648 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 8.1e+01/s
# 2025-06-12 10:09:02,680 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 7.6e+01/s
# 2025-06-12 10:09:02,718 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.2e+01/s
# 2025-06-12 10:09:02,757 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.6e+01/s
# 2025-06-12 10:09:02,789 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 8.1e+01/s
# 2025-06-12 10:09:02,823 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 7.1e+01/s
# 2025-06-12 10:09:02,856 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 7.8e+01/s
# 2025-06-12 10:09:02,890 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 7.0e+01/s
# 2025-06-12 10:09:02,925 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 7.0e+01/s
# 2025-06-12 10:09:02,958 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 8.2e+01/s
# 2025-06-12 10:09:02,990 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 8.3e+01/s
# 2025-06-12 10:09:03,023 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 8.0e+01/s
# 2025-06-12 10:09:03,055 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 8.2e+01/s
# 2025-06-12 10:09:03,086 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 8.4e+01/s
# 2025-06-12 10:09:03,118 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 8.4e+01/s
# 2025-06-12 10:09:03,150 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 8.2e+01/s
# 2025-06-12 10:09:03,183 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 7.8e+01/s
# 2025-06-12 10:09:03,215 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 8.2e+01/s
# 2025-06-12 10:09:03,248 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 8.4e+01/s
# 2025-06-12 10:09:03,280 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 8.3e+01/s
# 2025-06-12 10:09:03,315 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 7.1e+01/s
# 2025-06-12 10:09:03,350 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 8.3e+01/s
# 2025-06-12 10:09:03,382 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 8.3e+01/s
# 2025-06-12 10:09:03,414 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 8.0e+01/s
# 2025-06-12 10:09:03,452 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.3e+01/s
# 2025-06-12 10:09:03,491 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.7e+01/s
# 2025-06-12 10:09:03,531 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.2e+01/s
# 2025-06-12 10:09:03,566 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 8.2e+01/s
# 2025-06-12 10:09:03,602 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.5e+01/s
# 2025-06-12 10:09:03,634 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 8.1e+01/s
# 2025-06-12 10:09:03,667 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 7.8e+01/s
# 2025-06-12 10:09:03,699 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 7.6e+01/s
# 2025-06-12 10:09:03,731 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 8.3e+01/s
# 2025-06-12 10:09:03,763 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 8.4e+01/s
# 2025-06-12 10:09:03,796 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 7.9e+01/s
# 2025-06-12 10:09:03,829 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 7.9e+01/s
# 2025-06-12 10:09:03,868 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.7e+01/s

# %% [markdown]
# For the $k$ with the highest growth rate, we also find the eigenvector. This gives us the vertical profile of the most unstable mode.

# %%
k_max = k_ary[np.argmax(grow_ary)]

kx['g'] = k_max; ky['g'] = 0

solver = problem.build_solver()
solver.solve_dense(solver.subproblems[0], rebuild_matrices=True)
evals = solver.eigenvalues

loc_grow = np.argmax(np.imag(evals))

solver.set_state(loc_grow,0)
P0_evec = solver.state[0]['g'] # index 0 because P0 is the first element of the d3.EVP statement
# Out:
# 2025-06-12 10:10:46,322 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 4.8e+01/s

# %% [markdown]
# The below plot matches exactly {cite:t}`Vallis_17` Fig. 9.10.

# %%
# plot
fig=plt.figure(figsize=(5.5,5))

plt.subplot(2,2,1)
plt.plot(k_ary,grow_ary)
plt.ylim(0,0.4)

k_max = k_ary[np.argmax(grow_ary)]
plt.title("Growth rate")

plt.subplot(2,2,3)
plt.plot(k_ary,-np.real(c_ary_1),color=(0,0.4453125,0.6953125))
plt.plot(k_ary,-np.real(c_ary_2),color=(0,0.4453125,0.6953125))

plt.plot(k_ary,np.imag(c_ary_1),'--')

plt.legend(["$-C_r$",'__ok__',"$C_i$"])
plt.title("Wave speed $C_r$ and $C_i$")
plt.ylim(0,1)
plt.xlabel("$k$")

plt.subplot(2,2,2)
plt.plot(np.angle(P0_evec)-np.angle(P0_evec[0]),z[0].ravel())
plt.xlim(0,2)
plt.title("Phase of eigenvector")
plt.ylim(-1,0)
plt.ylabel("$z$")

plt.subplot(2,2,4)
plt.plot(np.abs(P0_evec)/np.abs(P0_evec[0]),z[0].ravel())
plt.xlim(0.5,1)
plt.title("Magnitude of eigenvector")
plt.ylim(-1,0)
plt.ylabel("$z$")

fig.tight_layout(pad=0.6)
plt.show()

# %% [markdown]
# We evaluate for the $b$ and $v$ fields of the most unstable mode.

# %%
b = dist.Field(bases=zbasis )
v = dist.Field(bases=zbasis )

# Problem
problem_morefields = d3.LBVP([v, b], namespace=locals())

problem_morefields.add_equation("v = dx(P0)")
problem_morefields.add_equation("b = dz(P0)")
# Out:
# {'eqn': Add(Convert(<Field 134250239443376>), Mul(-1, Diff(<Field 134250388118736>))),
#  'LHS': <Field 134250239443376>,
#  'RHS': Diff(<Field 134250388118736>),
#  'condition': 'True',
#  'tensorsig': (),
#  'dtype': dtype('complex128'),
#  'valid_modes': array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True]),
#  'L': Convert(<Field 134250239443376>),
#  'F': Diff(<Field 134250388118736>),
#  'domain': <dedalus.core.domain.Domain at 0x7a199ab3df90>,
#  'matrix_dependence': array([ True]),
#  'matrix_coupling': array([ True])}

# %%
P0['g'] = P0_evec

# Solver
solver_morefields = problem_morefields.build_solver()
solver_morefields.solve()
# Out:
# 2025-06-12 10:14:11,741 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.9e+01/s

# %% [markdown]
# The below plot matches exactly {cite:t}`Vallis_17` Fig. 9.12.

# %%
x = np.arange(0,3*np.pi,0.05)
phs_corr = np.exp(1j*1.5*x)

fig=plt.figure(figsize=(5.5,6))

plt.subplot(3,1,1)
P0eig_mat = np.outer(P0['g'],phs_corr)
plt.contour(x,z[0].ravel(),P0eig_mat.real, 10, cmap=cmo.balance, norm=colors.CenteredNorm())
plt.xticks([]); plt.yticks([])
plt.title(r"$\psi$")

plt.subplot(3,1,2)
beig_mat = np.outer(b['g'],phs_corr)
plt.contour(x,z[0].ravel(),beig_mat.real, 10, cmap=cmo.balance, norm=colors.CenteredNorm())
plt.xticks([]); plt.yticks([])
plt.title("$b$")

plt.subplot(3,1,3)
veig_mat = np.outer(v['g'],phs_corr)
plt.contour(x,z[0].ravel(),veig_mat.real, 10, cmap=cmo.balance, norm=colors.CenteredNorm())
plt.yticks([])
plt.title("$v$")

plt.show()

# %% [markdown]
# The below plot matches exactly {cite:t}`Vallis_17` Fig. 9.11. This is left as an excercise for the reader.
